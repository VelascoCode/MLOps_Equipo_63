# %%
# !pip install evidently
# Out:
# ...
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.5 MB 1.5 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.5 MB 1.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.3/4.5 MB 1.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.8/4.5 MB 1.8 MB/s eta 0:00:02
#    --------------------- ------------------ 2.4/4.5 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.1/4.5 MB 2.1 MB/s eta 0:00:01
#    -------------------------------- ------- 3.7/4.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 4.2/4.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 2.2 MB/s  0:00:02
# ...

# %%
import pandas as pd
from sklearn import datasets
    
from evidently import Dataset
from evidently import DataDefinition
from evidently import Report
from evidently.presets import DataDriftPreset, DataSummaryPreset

from evidently.ui.workspace import CloudWorkspace

# %%
ws = CloudWorkspace(token="dG9rbgGjZgySQVtAJbEjpYNmlUMDthiKKGdDSOhkgJQYxCdUTQBQA8k0WUPNmIRypC9tq4VRl2mo9y8TJbsaIUE34PY8CqpzDYZdjFjb/OjaPvNWMiCANAcrfzdINm83/bnfgruAdUml6Csp9AJE51MVC6N3fcxp6KTv", url="https://app.evidently.cloud")
project = ws.create_project("Mashable News Popularity", org_id="019a94d0-d7f9-7c34-bf48-af5ac9a80801")
project.description = "Project to monitor Mashable News Popularity dataset - Equipo 63 MLOps"
project.save()

# or project = ws.get_project("PROJECT_ID")

# %%
# Datasets
og = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\processed\dataset_processed.csv")
drift_1 = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\monitoring\20251111T001117Z\monitor_mean_shift_delta_0.2.csv")
drift_2 = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\monitoring\20251111T001117Z\monitor_mean_shift_delta_0.5.csv")
drift_3 = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\monitoring\20251111T001117Z\monitor_mean_shift_delta_1.0.csv")
drift_4 = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\monitoring\20251111T001117Z\monitor_mean_shift_delta_2.0.csv")
missing_1 = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\monitoring\20251111T001117Z\monitor_missing_rate_5.csv")
missing_2 = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\monitoring\20251111T001117Z\monitor_missing_rate_20.csv")
missing_3 = pd.read_csv(r"C:\Users\Diego\Github_MLops\MLOps_Equipo_63\data\monitoring\20251111T001117Z\monitor_missing_rate_50.csv")

data_definition = DataDefinition(
    numerical_columns= [feat for feat in og.columns if og[feat].dtype in ['int64', 'float64']],
    categorical_columns= [feat for feat in og.columns if og[feat].dtype == 'object']
)

og = Dataset.from_pandas(og, data_definition=data_definition)
drift_1 = Dataset.from_pandas(drift_1, data_definition=data_definition)
drift_2 = Dataset.from_pandas(drift_2, data_definition=data_definition)
drift_3 = Dataset.from_pandas(drift_3, data_definition=data_definition)
drift_4 = Dataset.from_pandas(drift_4, data_definition=data_definition)
missing_1 = Dataset.from_pandas(missing_1, data_definition=data_definition)
missing_2 = Dataset.from_pandas(missing_2, data_definition=data_definition)
missing_3 = Dataset.from_pandas(missing_3, data_definition=data_definition)

# %%
report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval_1 = report.run(reference_data=og, current_data=drift_1)
ws.add_run(project.id, eval_1, name="Mean Shift Delta 0.2", include_data=False)

report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval_2 = report.run(reference_data=og, current_data=drift_2)
ws.add_run(project.id, eval_2, name="Mean Shift Delta 0.5", include_data=False)
    
report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval_3 = report.run(reference_data=og, current_data=drift_3)
ws.add_run(project.id, eval_3, name="Mean Shift Delta 1.0", include_data=False)

report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval_4 = report.run(reference_data=og, current_data=drift_4)
ws.add_run(project.id, eval_4, name="Mean Shift Delta 2.0", include_data=False)

report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval_5 = report.run(reference_data=og, current_data=missing_1)
ws.add_run(project.id, eval_5, name="Missing Rate 5%", include_data=False)
    
report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval_6 = report.run(reference_data=og, current_data=missing_2)
ws.add_run(project.id, eval_6, name="Missing Rate 20%", include_data=False)

report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval_7 = report.run(reference_data=og, current_data=missing_3)
ws.add_run(project.id, eval_7, name="Missing Rate 50%", include_data=False)
# Out:
# c:\Users\Diego\.conda\envs\env_mlops\Lib\site-packages\numpy\lib\_function_base_impl.py:3065: RuntimeWarning:
#
# invalid value encountered in divide
#
# c:\Users\Diego\.conda\envs\env_mlops\Lib\site-packages\numpy\lib\_function_base_impl.py:3066: RuntimeWarning:
#
# invalid value encountered in divide
#
# c:\Users\Diego\.conda\envs\env_mlops\Lib\site-packages\numpy\lib\_function_base_impl.py:3065: RuntimeWarning:
#
# invalid value encountered in divide
#
# c:\Users\Diego\.conda\envs\env_mlops\Lib\site-packages\numpy\lib\_function_base_impl.py:3066: RuntimeWarning:
#
# invalid value encountered in divide
#
# c:\Users\Diego\.conda\envs\env_mlops\Lib\site-packages\numpy\lib\_function_base_impl.py:3065: RuntimeWarning:
#
# invalid value encountered in divide
#
# c:\Users\Diego\.conda\envs\env_mlops\Lib\site-packages\numpy\lib\_function_base_impl.py:3066: RuntimeWarning:
#
# invalid value encountered in divide
#
# ...
